# %% [markdown]
# # Week 10 - Class 9
#
# This notebook have the most important exercises for theoretical class 9, which covers chapter 8, and 9 from the book. The labs from https://github.com/fchollet/deep-learning-with-python-notebooks are a guide for this notebook, mainly the labs 8,9.
#
# It will be covered:
# - Image classification VGG16
# - Image Segmentation
# -

# %%
from tensorflow import keras
from tensorflow.keras import layers

import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
# Out:
# 2023-02-15 09:31:40.641431: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Image Classification

# %% [markdown]
# ## Data processing

# %%
#!mkdir ~/.kaggle
#!cp kaggle.json ~/.kaggle/
#!chmod 600 ~/.kaggle/kaggle.json
#!kaggle competitions download -c dogs-vs-cats
#!unzip -qq dogs-vs-cats.zip
#!unzip -qq train.zip

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[11], line 15
#      11         for fname in fnames:
#      12             shutil.copyfile(src=original_dir / fname,
#      13                             dst=dir / fname)
# ---> 15 make_subset("train", start_index=0, end_index=1000)
#      16 make_subset("validation", start_index=1000, end_index=1500)
#      17 make_subset("test", start_index=1500, end_index=2500)
#
# Cell In[11], line 9, in make_subset(subset_name, start_index, end_index)
#       7 for category in ("cat", "dog"):
#       8     dir = new_base_dir / subset_name / category
# ----> 9     os.makedirs(dir)
#      10     fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
#      11     for fname in fnames:
#
# File ~/miniconda3/envs/tf-py38/lib/python3.8/os.py:223, in makedirs(name, mode, exist_ok)
#     221         return
#     222 try:
# --> 223     mkdir(name, mode)
#     224 except OSError:
#     225     # Cannot rely on checking for EEXIST, since the operating system
#     226     # could give priority to other errors like EACCES or EROFS
#     227     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [Errno 17] File exists: 'cats_vs_dogs_small/train/cat'

# %% [markdown]
# 1.1 Which type of keras model is this? (Sequential, Functional, Multi)
#
# 1.2 What is the input shape?
#
# 1.3 How many outputs the NN has? Which type of algorithm is this?

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_7 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_8 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 18, 18, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 256)         590080
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 1.4 Choose the apropriate loss and metric:

# %%
model.compile(loss=<your-answer>,
              optimizer="rmsprop",
              metrics=[<your-answer>])

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %%
for data_batch, labels_batch in test_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# 1.5 Build a call back to save only the best model checkpoint, monitoring the validation loss, and saving the keras model in this directory with the name 'convnet_from_scratch.keras'
#
# tip: check the callbacks from last lab

# %%
callbacks = [
    <your-answer>
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 5s 51ms/step - loss: 0.7066 - accuracy: 0.5200 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 2/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.6947 - accuracy: 0.5440 - val_loss: 0.6855 - val_accuracy: 0.5230
# Epoch 3/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.6810 - accuracy: 0.5710 - val_loss: 0.6639 - val_accuracy: 0.5820
# Epoch 4/30
# 63/63 [==============================] - 3s 39ms/step - loss: 0.6520 - accuracy: 0.6335 - val_loss: 0.6458 - val_accuracy: 0.6140
# Epoch 5/30
# 63/63 [==============================] - 3s 40ms/step - loss: 0.6384 - accuracy: 0.6550 - val_loss: 0.6140 - val_accuracy: 0.6620
# Epoch 6/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.5865 - accuracy: 0.6860 - val_loss: 0.6278 - val_accuracy: 0.6870
# Epoch 7/30
# 63/63 [==============================] - 3s 39ms/step - loss: 0.5458 - accuracy: 0.7150 - val_loss: 0.6061 - val_accuracy: 0.7080
# Epoch 8/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.5126 - accuracy: 0.7385 - val_loss: 0.6645 - val_accuracy: 0.6580
# Epoch 9/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.4704 - accuracy: 0.7825 - val_loss: 0.6338 - val_accuracy: 0.6890
# Epoch 10/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.4199 - accuracy: 0.8105 - val_loss: 0.6448 - val_accuracy: 0.7090
# Epoch 11/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.3963 - accuracy: 0.8255 - val_loss: 0.6681 - val_accuracy: 0.6760
# Epoch 12/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.3248 - accuracy: 0.8565 - val_loss: 0.8769 - val_accuracy: 0.6550
# Epoch 13/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.2834 - accuracy: 0.8825 - val_loss: 0.8669 - val_accuracy: 0.6880
# Epoch 14/30
# 63/63 [==============================] - 2s 38ms/step - loss: 0.2253 - accuracy: 0.9065 - val_loss: 1.3048 - val_accuracy: 0.6980
# Epoch 15/30
# 63/63 [==============================] - 2s 38ms/step - loss: 0.1805 - accuracy: 0.9320 - val_loss: 1.0758 - val_accuracy: 0.6970
# Epoch 16/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.1428 - accuracy: 0.9425 - val_loss: 1.0633 - val_accuracy: 0.6930
# Epoch 17/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.1184 - accuracy: 0.9540 - val_loss: 1.3029 - val_accuracy: 0.6840
# Epoch 18/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0877 - accuracy: 0.9665 - val_loss: 1.4970 - val_accuracy: 0.7030
# Epoch 19/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0811 - accuracy: 0.9675 - val_loss: 2.5682 - val_accuracy: 0.6700
# Epoch 20/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0849 - accuracy: 0.9695 - val_loss: 1.9796 - val_accuracy: 0.6890
# Epoch 21/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0608 - accuracy: 0.9840 - val_loss: 1.7076 - val_accuracy: 0.6720
# Epoch 22/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0698 - accuracy: 0.9770 - val_loss: 1.7248 - val_accuracy: 0.6940
# Epoch 23/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0660 - accuracy: 0.9775 - val_loss: 1.9344 - val_accuracy: 0.6930
# Epoch 24/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0367 - accuracy: 0.9855 - val_loss: 2.3095 - val_accuracy: 0.6940
# Epoch 25/30
# 63/63 [==============================] - 2s 38ms/step - loss: 0.0592 - accuracy: 0.9825 - val_loss: 2.2535 - val_accuracy: 0.7010
# Epoch 26/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0421 - accuracy: 0.9875 - val_loss: 2.5018 - val_accuracy: 0.6960
# Epoch 27/30
# 63/63 [==============================] - 3s 42ms/step - loss: 0.0484 - accuracy: 0.9895 - val_loss: 2.3654 - val_accuracy: 0.6720
# Epoch 28/30
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0537 - accuracy: 0.9840 - val_loss: 2.2817 - val_accuracy: 0.7020
# Epoch 29/30
# 63/63 [==============================] - 3s 39ms/step - loss: 0.0428 - accuracy: 0.9885 - val_loss: 2.3094 - val_accuracy: 0.6960
# Epoch 30/30
# 63/63 [==============================] - 3s 39ms/step - loss: 0.0710 - accuracy: 0.9835 - val_loss: 2.3064 - val_accuracy: 0.6970

# %% [markdown]
# 1.6 Define the overfitting zone in both graphics:

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 1s 13ms/step - loss: 0.6255 - accuracy: 0.6965
# Test accuracy: 0.697

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# 1.7 Why are we doing data augmentation? Connect your answer with the validation and training loss trends through epochs.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[2].numpy().astype("uint8"))
        plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# ## Regularization

# %% [markdown]
# Defining a new convnet that includes image augmentation and dropout

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
#with 15min of training (100 epochs), data augmentation and dropout 
# went from 70% to 77% in val acc (without adding data!)
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 12s 134ms/step - loss: 0.6969 - accuracy: 0.5070 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/100
# 63/63 [==============================] - 8s 128ms/step - loss: 0.6936 - accuracy: 0.5075 - val_loss: 0.6893 - val_accuracy: 0.5040
# Epoch 3/100
# 63/63 [==============================] - 8s 130ms/step - loss: 0.6871 - accuracy: 0.5505 - val_loss: 0.6670 - val_accuracy: 0.6120
# Epoch 4/100
# 63/63 [==============================] - 8s 125ms/step - loss: 0.6673 - accuracy: 0.6115 - val_loss: 0.6613 - val_accuracy: 0.5900
# Epoch 5/100
# 63/63 [==============================] - 8s 132ms/step - loss: 0.6531 - accuracy: 0.6315 - val_loss: 0.6453 - val_accuracy: 0.6100
# Epoch 6/100
# 63/63 [==============================] - 9s 134ms/step - loss: 0.6288 - accuracy: 0.6610 - val_loss: 0.7450 - val_accuracy: 0.5540
# Epoch 7/100
# 63/63 [==============================] - 8s 130ms/step - loss: 0.6239 - accuracy: 0.6540 - val_loss: 0.6055 - val_accuracy: 0.6490
# Epoch 8/100
# 63/63 [==============================] - 8s 128ms/step - loss: 0.5978 - accuracy: 0.6780 - val_loss: 0.5943 - val_accuracy: 0.6870
# Epoch 9/100
# 63/63 [==============================] - 8s 130ms/step - loss: 0.5753 - accuracy: 0.6950 - val_loss: 0.5996 - val_accuracy: 0.6570
# Epoch 10/100
# 63/63 [==============================] - 8s 127ms/step - loss: 0.5771 - accuracy: 0.7085 - val_loss: 0.6332 - val_accuracy: 0.6450
# Epoch 11/100
# 63/63 [==============================] - 8s 125ms/step - loss: 0.5759 - accuracy: 0.7075 - val_loss: 0.7813 - val_accuracy: 0.6410
# Epoch 12/100
# 63/63 [==============================] - 8s 129ms/step - loss: 0.5634 - accuracy: 0.7030 - val_loss: 0.5845 - val_accuracy: 0.6940
# Epoch 13/100
# 63/63 [==============================] - 8s 128ms/step - loss: 0.5455 - accuracy: 0.7330 - val_loss: 0.6085 - val_accuracy: 0.6910
# Epoch 14/100
# 63/63 [==============================] - 8s 128ms/step - loss: 0.5341 - accuracy: 0.7350 - val_loss: 0.6063 - val_accuracy: 0.6760
# Epoch 15/100
# 63/63 [==============================] - 8s 130ms/step - loss: 0.5253 - accuracy: 0.7515 - val_loss: 0.6165 - val_accuracy: 0.6790
# Epoch 16/100
# 63/63 [==============================] - 8s 129ms/step - loss: 0.5167 - accuracy: 0.7535 - val_loss: 0.5961 - val_accuracy: 0.6930
# Epoch 17/100
# 63/63 [==============================] - 8s 124ms/step - loss: 0.4977 - accuracy: 0.7570 - val_loss: 0.5452 - val_accuracy: 0.7300
# Epoch 18/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.4932 - accuracy: 0.7610 - val_loss: 0.6059 - val_accuracy: 0.6970
# Epoch 19/100
# 63/63 [==============================] - 8s 123ms/step - loss: 0.4926 - accuracy: 0.7620 - val_loss: 0.6385 - val_accuracy: 0.7030
# Epoch 20/100
# 63/63 [==============================] - 8s 121ms/step - loss: 0.4730 - accuracy: 0.7715 - val_loss: 0.5841 - val_accuracy: 0.7240
# Epoch 21/100
# 63/63 [==============================] - 8s 121ms/step - loss: 0.4656 - accuracy: 0.7870 - val_loss: 0.6261 - val_accuracy: 0.7280
# Epoch 22/100
# 63/63 [==============================] - 7s 117ms/step - loss: 0.4502 - accuracy: 0.7835 - val_loss: 0.5582 - val_accuracy: 0.7430
# Epoch 23/100
# 63/63 [==============================] - 8s 128ms/step - loss: 0.4420 - accuracy: 0.7960 - val_loss: 0.5614 - val_accuracy: 0.7350
# Epoch 24/100
# 63/63 [==============================] - 8s 125ms/step - loss: 0.4352 - accuracy: 0.7915 - val_loss: 0.5672 - val_accuracy: 0.7280
# Epoch 25/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.4284 - accuracy: 0.7985 - val_loss: 0.4847 - val_accuracy: 0.7740
# Epoch 26/100
# 63/63 [==============================] - 8s 126ms/step - loss: 0.3981 - accuracy: 0.8140 - val_loss: 0.5751 - val_accuracy: 0.7460
# Epoch 27/100
# 63/63 [==============================] - 8s 121ms/step - loss: 0.4058 - accuracy: 0.8260 - val_loss: 0.5307 - val_accuracy: 0.7660
# Epoch 28/100
# 63/63 [==============================] - 7s 117ms/step - loss: 0.3897 - accuracy: 0.8290 - val_loss: 0.5929 - val_accuracy: 0.7310
# Epoch 29/100
# 63/63 [==============================] - 7s 119ms/step - loss: 0.3791 - accuracy: 0.8360 - val_loss: 0.6044 - val_accuracy: 0.7670
# Epoch 30/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.3858 - accuracy: 0.8260 - val_loss: 0.5815 - val_accuracy: 0.7650
# Epoch 31/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.3669 - accuracy: 0.8335 - val_loss: 0.6999 - val_accuracy: 0.7350
# Epoch 32/100
# 63/63 [==============================] - 8s 126ms/step - loss: 0.3705 - accuracy: 0.8415 - val_loss: 0.6083 - val_accuracy: 0.7520
# Epoch 33/100
# 63/63 [==============================] - 8s 127ms/step - loss: 0.3433 - accuracy: 0.8495 - val_loss: 0.5840 - val_accuracy: 0.7790
# Epoch 34/100
# 63/63 [==============================] - 8s 126ms/step - loss: 0.3294 - accuracy: 0.8590 - val_loss: 0.6185 - val_accuracy: 0.7700
# Epoch 35/100
# 63/63 [==============================] - 8s 124ms/step - loss: 0.3225 - accuracy: 0.8555 - val_loss: 0.6929 - val_accuracy: 0.7600
# Epoch 36/100
# 63/63 [==============================] - 8s 123ms/step - loss: 0.2998 - accuracy: 0.8715 - val_loss: 0.5539 - val_accuracy: 0.7840
# Epoch 37/100
# 63/63 [==============================] - 8s 123ms/step - loss: 0.3088 - accuracy: 0.8725 - val_loss: 0.6644 - val_accuracy: 0.7870
# Epoch 38/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.3075 - accuracy: 0.8665 - val_loss: 0.5513 - val_accuracy: 0.7850
# Epoch 39/100
# 63/63 [==============================] - 8s 126ms/step - loss: 0.3022 - accuracy: 0.8650 - val_loss: 0.6781 - val_accuracy: 0.7650
# Epoch 40/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.2972 - accuracy: 0.8725 - val_loss: 0.6927 - val_accuracy: 0.7630
# Epoch 41/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.2729 - accuracy: 0.8915 - val_loss: 0.7787 - val_accuracy: 0.7650
# Epoch 42/100
# 63/63 [==============================] - 8s 126ms/step - loss: 0.2690 - accuracy: 0.8890 - val_loss: 0.7343 - val_accuracy: 0.7790
# Epoch 43/100
# 63/63 [==============================] - 8s 123ms/step - loss: 0.2399 - accuracy: 0.8950 - val_loss: 0.7988 - val_accuracy: 0.7610
# Epoch 44/100
# 63/63 [==============================] - 8s 124ms/step - loss: 0.2479 - accuracy: 0.8930 - val_loss: 0.6010 - val_accuracy: 0.8010
# Epoch 45/100
# 63/63 [==============================] - 8s 125ms/step - loss: 0.2531 - accuracy: 0.8975 - val_loss: 0.5884 - val_accuracy: 0.7850
# Epoch 46/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.2501 - accuracy: 0.9005 - val_loss: 0.6395 - val_accuracy: 0.7890
# Epoch 47/100
# 63/63 [==============================] - 8s 121ms/step - loss: 0.2292 - accuracy: 0.9120 - val_loss: 0.6912 - val_accuracy: 0.7670
# Epoch 48/100
# 63/63 [==============================] - 8s 120ms/step - loss: 0.2533 - accuracy: 0.8940 - val_loss: 0.6508 - val_accuracy: 0.8030
# Epoch 49/100
# 63/63 [==============================] - 8s 125ms/step - loss: 0.2134 - accuracy: 0.9140 - val_loss: 0.7766 - val_accuracy: 0.7930
# Epoch 50/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.2139 - accuracy: 0.9160 - val_loss: 0.7663 - val_accuracy: 0.7690
# Epoch 51/100
# 63/63 [==============================] - 8s 121ms/step - loss: 0.2086 - accuracy: 0.9135 - val_loss: 0.9565 - val_accuracy: 0.7720
# Epoch 52/100
# 63/63 [==============================] - 8s 120ms/step - loss: 0.2116 - accuracy: 0.9165 - val_loss: 0.7449 - val_accuracy: 0.7890
# Epoch 53/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.1835 - accuracy: 0.9235 - val_loss: 0.8605 - val_accuracy: 0.7810
# Epoch 54/100
# 63/63 [==============================] - 8s 126ms/step - loss: 0.2093 - accuracy: 0.9145 - val_loss: 0.6765 - val_accuracy: 0.7910
# Epoch 55/100
# 63/63 [==============================] - 8s 120ms/step - loss: 0.1954 - accuracy: 0.9190 - val_loss: 0.7504 - val_accuracy: 0.7950
# Epoch 56/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.1936 - accuracy: 0.9300 - val_loss: 0.8701 - val_accuracy: 0.7760
# Epoch 57/100
# 63/63 [==============================] - 8s 123ms/step - loss: 0.1878 - accuracy: 0.9295 - val_loss: 0.7115 - val_accuracy: 0.8080
# Epoch 58/100
# 63/63 [==============================] - 7s 117ms/step - loss: 0.1740 - accuracy: 0.9335 - val_loss: 0.9019 - val_accuracy: 0.7930
# Epoch 59/100
# 63/63 [==============================] - 7s 118ms/step - loss: 0.1970 - accuracy: 0.9270 - val_loss: 0.7364 - val_accuracy: 0.8050
# Epoch 60/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.1569 - accuracy: 0.9395 - val_loss: 0.7602 - val_accuracy: 0.8030
# Epoch 61/100
# 63/63 [==============================] - 8s 120ms/step - loss: 0.1634 - accuracy: 0.9365 - val_loss: 0.7531 - val_accuracy: 0.7950
# Epoch 62/100
# 63/63 [==============================] - 7s 118ms/step - loss: 0.1632 - accuracy: 0.9450 - val_loss: 0.8028 - val_accuracy: 0.7890
# Epoch 63/100
# 63/63 [==============================] - 8s 131ms/step - loss: 0.1627 - accuracy: 0.9390 - val_loss: 0.9063 - val_accuracy: 0.7790
# Epoch 64/100
# 63/63 [==============================] - 8s 121ms/step - loss: 0.1642 - accuracy: 0.9420 - val_loss: 0.8249 - val_accuracy: 0.7920
# Epoch 65/100
# 63/63 [==============================] - 8s 123ms/step - loss: 0.1689 - accuracy: 0.9325 - val_loss: 0.8061 - val_accuracy: 0.8060
# Epoch 66/100
# 63/63 [==============================] - 8s 120ms/step - loss: 0.1469 - accuracy: 0.9420 - val_loss: 0.9213 - val_accuracy: 0.7870
# Epoch 67/100
# 63/63 [==============================] - 8s 123ms/step - loss: 0.1521 - accuracy: 0.9445 - val_loss: 0.8796 - val_accuracy: 0.7850
# Epoch 68/100
# 63/63 [==============================] - 8s 124ms/step - loss: 0.1313 - accuracy: 0.9485 - val_loss: 0.8888 - val_accuracy: 0.8060
# Epoch 69/100
# 63/63 [==============================] - 8s 124ms/step - loss: 0.1462 - accuracy: 0.9435 - val_loss: 1.0695 - val_accuracy: 0.7840
# Epoch 70/100
# 63/63 [==============================] - 8s 128ms/step - loss: 0.1496 - accuracy: 0.9430 - val_loss: 0.8448 - val_accuracy: 0.7880
# Epoch 71/100
# 63/63 [==============================] - 8s 126ms/step - loss: 0.1732 - accuracy: 0.9410 - val_loss: 0.8936 - val_accuracy: 0.8100
# Epoch 72/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.1938 - accuracy: 0.9410 - val_loss: 0.7881 - val_accuracy: 0.8050
# Epoch 73/100
# 63/63 [==============================] - 8s 121ms/step - loss: 0.1226 - accuracy: 0.9555 - val_loss: 0.9266 - val_accuracy: 0.8070
# Epoch 74/100
# 63/63 [==============================] - 7s 118ms/step - loss: 0.1328 - accuracy: 0.9520 - val_loss: 1.0481 - val_accuracy: 0.7920
# Epoch 75/100
# 63/63 [==============================] - 8s 124ms/step - loss: 0.1461 - accuracy: 0.9520 - val_loss: 1.1585 - val_accuracy: 0.7760
# Epoch 76/100
# 63/63 [==============================] - 8s 126ms/step - loss: 0.1393 - accuracy: 0.9510 - val_loss: 0.9737 - val_accuracy: 0.8120
# Epoch 77/100
# 63/63 [==============================] - 8s 129ms/step - loss: 0.1224 - accuracy: 0.9505 - val_loss: 1.0812 - val_accuracy: 0.8000
# Epoch 78/100
# 63/63 [==============================] - 8s 123ms/step - loss: 0.1402 - accuracy: 0.9540 - val_loss: 1.0033 - val_accuracy: 0.8140
# Epoch 79/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.1278 - accuracy: 0.9535 - val_loss: 0.9525 - val_accuracy: 0.7950
# Epoch 80/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.1048 - accuracy: 0.9600 - val_loss: 1.1601 - val_accuracy: 0.7740
# Epoch 81/100
# 63/63 [==============================] - 8s 124ms/step - loss: 0.1317 - accuracy: 0.9580 - val_loss: 1.2022 - val_accuracy: 0.7740
# Epoch 82/100
# 63/63 [==============================] - 8s 120ms/step - loss: 0.1387 - accuracy: 0.9485 - val_loss: 0.8697 - val_accuracy: 0.7930
# Epoch 83/100
# 63/63 [==============================] - 8s 121ms/step - loss: 0.1323 - accuracy: 0.9545 - val_loss: 1.3702 - val_accuracy: 0.7510
# Epoch 84/100
# 63/63 [==============================] - 8s 123ms/step - loss: 0.1373 - accuracy: 0.9535 - val_loss: 0.9472 - val_accuracy: 0.8120
# Epoch 85/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.1664 - accuracy: 0.9425 - val_loss: 1.0107 - val_accuracy: 0.7650
# Epoch 86/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.1233 - accuracy: 0.9610 - val_loss: 1.0959 - val_accuracy: 0.8020
# Epoch 87/100
# 63/63 [==============================] - 7s 118ms/step - loss: 0.0992 - accuracy: 0.9665 - val_loss: 1.1641 - val_accuracy: 0.7950
# Epoch 88/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.1015 - accuracy: 0.9605 - val_loss: 1.2636 - val_accuracy: 0.7970
# Epoch 89/100
# 63/63 [==============================] - 7s 115ms/step - loss: 0.1345 - accuracy: 0.9580 - val_loss: 0.9747 - val_accuracy: 0.8040
# Epoch 90/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.1096 - accuracy: 0.9670 - val_loss: 0.9349 - val_accuracy: 0.8310
# Epoch 91/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.1158 - accuracy: 0.9595 - val_loss: 1.0463 - val_accuracy: 0.8140
# Epoch 92/100
# 63/63 [==============================] - 7s 118ms/step - loss: 0.1119 - accuracy: 0.9615 - val_loss: 1.1648 - val_accuracy: 0.8090
# Epoch 93/100
# 63/63 [==============================] - 8s 124ms/step - loss: 0.1276 - accuracy: 0.9580 - val_loss: 0.9810 - val_accuracy: 0.8110
# Epoch 94/100
# 63/63 [==============================] - 8s 125ms/step - loss: 0.1131 - accuracy: 0.9590 - val_loss: 1.1490 - val_accuracy: 0.8010
# Epoch 95/100
# 63/63 [==============================] - 8s 119ms/step - loss: 0.1265 - accuracy: 0.9625 - val_loss: 1.1388 - val_accuracy: 0.8120
# Epoch 96/100
# 63/63 [==============================] - 8s 122ms/step - loss: 0.0967 - accuracy: 0.9670 - val_loss: 1.1818 - val_accuracy: 0.7660
# Epoch 97/100
# 63/63 [==============================] - 8s 128ms/step - loss: 0.1140 - accuracy: 0.9590 - val_loss: 1.1062 - val_accuracy: 0.7970
# Epoch 98/100
# 63/63 [==============================] - 8s 124ms/step - loss: 0.1271 - accuracy: 0.9600 - val_loss: 1.2232 - val_accuracy: 0.8090
# Epoch 99/100
# 63/63 [==============================] - 8s 126ms/step - loss: 0.1357 - accuracy: 0.9600 - val_loss: 1.1981 - val_accuracy: 0.8110
# Epoch 100/100
# 63/63 [==============================] - 7s 116ms/step - loss: 0.1193 - accuracy: 0.9590 - val_loss: 1.1249 - val_accuracy: 0.8000

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 1s 13ms/step - loss: 0.5237 - accuracy: 0.7740
# Test accuracy: 0.774

# %% [markdown]
# # Transfer Learning without data augmentation

# %% [markdown]
# 1.8 Which weight are we loading to the conv_base variable? From which layers?
#
# See what is the VGG16 architecture on the web, and connect the layers with the graphical represenatation of the NN

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
train_features.shape
# Out:
# (2000, 5, 5, 512)

# %% [markdown]
# 1.9 Check slides from class 8 (33-35), to add layers uppon previous NN, we need to do:
# - Flatten layer
# - Dense layer (you can choose the size and number)
# - Dropout layer (optional)
# - Dense layer as output (with the right number of classes)

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
      filepath="feature_extraction.keras",
      save_best_only=True,
      monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 7ms/step - loss: 13.2029 - accuracy: 0.9220 - val_loss: 3.9260 - val_accuracy: 0.9640
# Epoch 2/20
# 63/63 [==============================] - 0s 4ms/step - loss: 3.9420 - accuracy: 0.9725 - val_loss: 8.9898 - val_accuracy: 0.9550
# Epoch 3/20
# 63/63 [==============================] - 0s 4ms/step - loss: 1.7774 - accuracy: 0.9845 - val_loss: 6.3017 - val_accuracy: 0.9660
# Epoch 4/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.8117 - accuracy: 0.9900 - val_loss: 9.1958 - val_accuracy: 0.9550
# Epoch 5/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.9796 - accuracy: 0.9910 - val_loss: 3.8353 - val_accuracy: 0.9770
# Epoch 6/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.9246 - accuracy: 0.9925 - val_loss: 3.1844 - val_accuracy: 0.9770
# Epoch 7/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.5765 - accuracy: 0.9930 - val_loss: 3.6757 - val_accuracy: 0.9800
# Epoch 8/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.6039 - accuracy: 0.9940 - val_loss: 4.4294 - val_accuracy: 0.9750
# Epoch 9/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.2375 - accuracy: 0.9975 - val_loss: 4.7573 - val_accuracy: 0.9770
# Epoch 10/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1947 - accuracy: 0.9955 - val_loss: 4.6863 - val_accuracy: 0.9740
# Epoch 11/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0955 - accuracy: 0.9990 - val_loss: 5.2350 - val_accuracy: 0.9740
# Epoch 12/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1124 - accuracy: 0.9970 - val_loss: 4.8411 - val_accuracy: 0.9770
# Epoch 13/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1308 - accuracy: 0.9985 - val_loss: 4.6779 - val_accuracy: 0.9760
# Epoch 14/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.2058 - accuracy: 0.9990 - val_loss: 4.0422 - val_accuracy: 0.9780
# Epoch 15/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.3102 - accuracy: 0.9970 - val_loss: 4.5927 - val_accuracy: 0.9780
# Epoch 16/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9990 - val_loss: 3.9072 - val_accuracy: 0.9770
# Epoch 17/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0623 - accuracy: 0.9990 - val_loss: 4.2001 - val_accuracy: 0.9770
# Epoch 18/20
# 63/63 [==============================] - 0s 4ms/step - loss: 3.6165e-25 - accuracy: 1.0000 - val_loss: 4.2001 - val_accuracy: 0.9770
# Epoch 19/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.2115 - accuracy: 0.9980 - val_loss: 3.6119 - val_accuracy: 0.9770
# Epoch 20/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.1264 - accuracy: 0.9975 - val_loss: 6.8450 - val_accuracy: 0.9720

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# # Transfer Learning with data augmentation

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False

# %%
conv_base.trainable = True
print("This is the number of trainable weights "
      "before freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights before freezing the conv base: 26

# %%
conv_base.trainable = False
print("This is the number of trainable weights "
      "after freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights after freezing the conv base: 0

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x) #the data passes 1 time through the weight
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 17s 207ms/step - loss: 17.3334 - accuracy: 0.8895 - val_loss: 4.0121 - val_accuracy: 0.9730
# Epoch 2/50
# 63/63 [==============================] - 13s 207ms/step - loss: 6.3348 - accuracy: 0.9485 - val_loss: 3.4076 - val_accuracy: 0.9710
# Epoch 3/50
# 63/63 [==============================] - 13s 212ms/step - loss: 4.0346 - accuracy: 0.9635 - val_loss: 3.1945 - val_accuracy: 0.9830
# Epoch 4/50
# 63/63 [==============================] - 13s 205ms/step - loss: 4.3918 - accuracy: 0.9670 - val_loss: 4.0215 - val_accuracy: 0.9780
# Epoch 5/50
# 63/63 [==============================] - 13s 207ms/step - loss: 2.9816 - accuracy: 0.9710 - val_loss: 6.7316 - val_accuracy: 0.9670
# Epoch 6/50
# 63/63 [==============================] - 13s 206ms/step - loss: 2.3638 - accuracy: 0.9765 - val_loss: 4.0871 - val_accuracy: 0.9760
# Epoch 7/50
# 63/63 [==============================] - 13s 206ms/step - loss: 3.2721 - accuracy: 0.9730 - val_loss: 3.5042 - val_accuracy: 0.9790
# Epoch 8/50
# 63/63 [==============================] - 14s 215ms/step - loss: 2.9024 - accuracy: 0.9755 - val_loss: 2.7270 - val_accuracy: 0.9850
# Epoch 9/50
# 63/63 [==============================] - 13s 213ms/step - loss: 2.9671 - accuracy: 0.9725 - val_loss: 2.1476 - val_accuracy: 0.9850
# Epoch 10/50
# 63/63 [==============================] - 13s 204ms/step - loss: 2.0589 - accuracy: 0.9780 - val_loss: 5.2175 - val_accuracy: 0.9710
# Epoch 11/50
# 63/63 [==============================] - 13s 203ms/step - loss: 2.5940 - accuracy: 0.9790 - val_loss: 3.3492 - val_accuracy: 0.9820
# Epoch 12/50
# 63/63 [==============================] - 13s 207ms/step - loss: 1.2151 - accuracy: 0.9860 - val_loss: 2.5635 - val_accuracy: 0.9840
# Epoch 13/50
# 63/63 [==============================] - 13s 205ms/step - loss: 1.0645 - accuracy: 0.9825 - val_loss: 3.5329 - val_accuracy: 0.9800
# Epoch 14/50
# 63/63 [==============================] - 13s 206ms/step - loss: 1.3933 - accuracy: 0.9845 - val_loss: 3.1179 - val_accuracy: 0.9780
# Epoch 15/50
# 63/63 [==============================] - 15s 246ms/step - loss: 0.7087 - accuracy: 0.9910 - val_loss: 3.0639 - val_accuracy: 0.9790
# Epoch 16/50
# 63/63 [==============================] - 13s 203ms/step - loss: 1.5858 - accuracy: 0.9850 - val_loss: 3.0440 - val_accuracy: 0.9800
# Epoch 17/50
# 63/63 [==============================] - 13s 201ms/step - loss: 1.2005 - accuracy: 0.9855 - val_loss: 2.9851 - val_accuracy: 0.9830
# Epoch 18/50
# 63/63 [==============================] - 13s 207ms/step - loss: 1.8634 - accuracy: 0.9830 - val_loss: 3.4873 - val_accuracy: 0.9790
# Epoch 19/50
# 63/63 [==============================] - 13s 205ms/step - loss: 1.0583 - accuracy: 0.9875 - val_loss: 4.0290 - val_accuracy: 0.9760
# Epoch 20/50
# 63/63 [==============================] - 13s 208ms/step - loss: 1.3636 - accuracy: 0.9865 - val_loss: 3.5419 - val_accuracy: 0.9800
# Epoch 21/50
# 63/63 [==============================] - 13s 204ms/step - loss: 0.9993 - accuracy: 0.9890 - val_loss: 3.5443 - val_accuracy: 0.9810
# Epoch 22/50
# 63/63 [==============================] - 13s 206ms/step - loss: 0.7030 - accuracy: 0.9865 - val_loss: 4.4434 - val_accuracy: 0.9770
# Epoch 23/50
# 63/63 [==============================] - 13s 205ms/step - loss: 0.7565 - accuracy: 0.9895 - val_loss: 2.6416 - val_accuracy: 0.9820
# Epoch 24/50
# 63/63 [==============================] - 13s 207ms/step - loss: 0.9119 - accuracy: 0.9900 - val_loss: 4.9320 - val_accuracy: 0.9740
# Epoch 25/50
# 63/63 [==============================] - 13s 204ms/step - loss: 0.7495 - accuracy: 0.9880 - val_loss: 4.0457 - val_accuracy: 0.9710
# Epoch 26/50
# 63/63 [==============================] - 13s 206ms/step - loss: 0.7179 - accuracy: 0.9900 - val_loss: 5.6253 - val_accuracy: 0.9670
# Epoch 27/50
# 63/63 [==============================] - 13s 207ms/step - loss: 0.9583 - accuracy: 0.9880 - val_loss: 3.5370 - val_accuracy: 0.9820
# Epoch 28/50
# 63/63 [==============================] - 13s 202ms/step - loss: 0.6274 - accuracy: 0.9900 - val_loss: 2.4288 - val_accuracy: 0.9850
# Epoch 29/50
# 63/63 [==============================] - 13s 209ms/step - loss: 0.4616 - accuracy: 0.9945 - val_loss: 2.9147 - val_accuracy: 0.9780
# Epoch 30/50
# 63/63 [==============================] - 13s 208ms/step - loss: 0.5247 - accuracy: 0.9905 - val_loss: 2.8805 - val_accuracy: 0.9810
# Epoch 31/50
# 63/63 [==============================] - 13s 208ms/step - loss: 0.5227 - accuracy: 0.9905 - val_loss: 3.2969 - val_accuracy: 0.9790
# Epoch 32/50
# 63/63 [==============================] - 13s 209ms/step - loss: 0.4551 - accuracy: 0.9950 - val_loss: 3.1909 - val_accuracy: 0.9790
# Epoch 33/50
# 63/63 [==============================] - 13s 209ms/step - loss: 0.6097 - accuracy: 0.9905 - val_loss: 3.8192 - val_accuracy: 0.9770
# Epoch 34/50
# 63/63 [==============================] - 13s 206ms/step - loss: 0.3177 - accuracy: 0.9925 - val_loss: 2.8666 - val_accuracy: 0.9840
# Epoch 35/50
# 63/63 [==============================] - 13s 208ms/step - loss: 1.1541 - accuracy: 0.9900 - val_loss: 3.6358 - val_accuracy: 0.9810
# Epoch 36/50
# 63/63 [==============================] - 13s 206ms/step - loss: 0.9052 - accuracy: 0.9880 - val_loss: 3.4937 - val_accuracy: 0.9810
# Epoch 37/50
# 63/63 [==============================] - 13s 207ms/step - loss: 0.2625 - accuracy: 0.9935 - val_loss: 3.4675 - val_accuracy: 0.9780
# Epoch 38/50
# 63/63 [==============================] - 13s 208ms/step - loss: 0.2194 - accuracy: 0.9950 - val_loss: 3.3301 - val_accuracy: 0.9790
# Epoch 39/50
# 63/63 [==============================] - 13s 204ms/step - loss: 0.4240 - accuracy: 0.9940 - val_loss: 3.0128 - val_accuracy: 0.9830
# Epoch 40/50
# 63/63 [==============================] - 13s 205ms/step - loss: 0.4765 - accuracy: 0.9920 - val_loss: 3.6204 - val_accuracy: 0.9820
# Epoch 41/50
# 63/63 [==============================] - 13s 204ms/step - loss: 0.5108 - accuracy: 0.9935 - val_loss: 3.0178 - val_accuracy: 0.9810
# Epoch 42/50
# 63/63 [==============================] - 13s 208ms/step - loss: 0.2208 - accuracy: 0.9945 - val_loss: 4.0695 - val_accuracy: 0.9750
# Epoch 43/50
# 63/63 [==============================] - 13s 202ms/step - loss: 0.7886 - accuracy: 0.9910 - val_loss: 2.6619 - val_accuracy: 0.9820
# Epoch 44/50
# 63/63 [==============================] - 13s 207ms/step - loss: 0.2717 - accuracy: 0.9950 - val_loss: 2.3257 - val_accuracy: 0.9830
# Epoch 45/50
# 63/63 [==============================] - 13s 204ms/step - loss: 0.6699 - accuracy: 0.9940 - val_loss: 2.6955 - val_accuracy: 0.9830
# Epoch 46/50
# 63/63 [==============================] - 13s 202ms/step - loss: 0.3141 - accuracy: 0.9955 - val_loss: 2.6271 - val_accuracy: 0.9840
# Epoch 47/50
# 63/63 [==============================] - 13s 207ms/step - loss: 0.5287 - accuracy: 0.9935 - val_loss: 3.6395 - val_accuracy: 0.9790
# Epoch 48/50
# 63/63 [==============================] - 13s 204ms/step - loss: 0.5436 - accuracy: 0.9940 - val_loss: 2.7598 - val_accuracy: 0.9840
# Epoch 49/50
# 63/63 [==============================] - 13s 210ms/step - loss: 0.1979 - accuracy: 0.9960 - val_loss: 2.7702 - val_accuracy: 0.9840
# Epoch 50/50
# 63/63 [==============================] - 13s 203ms/step - loss: 0.2380 - accuracy: 0.9955 - val_loss: 2.3113 - val_accuracy: 0.9830

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 5s 82ms/step - loss: 3.3544 - accuracy: 0.9780
# Test accuracy: 0.978

# %% [markdown]
# # Fine Tuning

# %% [markdown]
# 2.0 What is the difference between transfer learning and fine tuning?

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")

# %% [markdown]
# # Image Segmentation

# %%
#!wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
#!wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
#!tar -xf images.tar.gz
#!tar -xf annotations.tar.gz

# %%
import os

input_dir = "images/"
target_dir = "annotations/trimaps/"

input_img_paths = sorted(
    [os.path.join(input_dir, fname)
     for fname in os.listdir(input_dir)
     if fname.endswith(".jpg")])
target_paths = sorted(
    [os.path.join(target_dir, fname)
     for fname in os.listdir(target_dir)
     if fname.endswith(".png") and not fname.startswith(".")])

# %%
plt.axis("off")
plt.imshow(load_img(input_img_paths[9]))

# %%
def display_target(target_array):
    normalized_array = (target_array.astype("uint8") - 1) * 127
    plt.axis("off")
    plt.imshow(normalized_array[:, :, 0])

img = img_to_array(load_img(target_paths[9], color_mode="grayscale"))
#display_target(img)

# %%
import numpy as np
import random

img_size = (200, 200)
num_imgs = len(input_img_paths)

random.Random(1337).shuffle(input_img_paths)
random.Random(1337).shuffle(target_paths)

def path_to_input_image(path):
    return img_to_array(load_img(path, target_size=img_size))

def path_to_target(path):
    img = img_to_array(
        load_img(path, target_size=img_size, color_mode="grayscale"))
    img = img.astype("uint8") - 1
    return img

input_imgs = np.zeros((num_imgs,) + img_size + (3,), dtype="float32")
targets = np.zeros((num_imgs,) + img_size + (1,), dtype="uint8")
for i in range(num_imgs):
    input_imgs[i] = path_to_input_image(input_img_paths[i])
    targets[i] = path_to_target(target_paths[i])

num_val_samples = 1000
train_input_imgs = input_imgs[:-num_val_samples]
train_targets = targets[:-num_val_samples]
val_input_imgs = input_imgs[-num_val_samples:]
val_targets = targets[-num_val_samples:]

# %%
from tensorflow import keras
from tensorflow.keras import layers

def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))
    x = layers.Rescaling(1./255)(inputs)

    x = layers.Conv2D(64, 3, strides=2, activation="relu", padding="same")(x)
    x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(128, 3, strides=2, activation="relu", padding="same")(x)
    x = layers.Conv2D(128, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(256, 3, strides=2, padding="same", activation="relu")(x)
    x = layers.Conv2D(256, 3, activation="relu", padding="same")(x)

    x = layers.Conv2DTranspose(256, 3, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(256, 3, activation="relu", padding="same", strides=2)(x)
    x = layers.Conv2DTranspose(128, 3, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(128, 3, activation="relu", padding="same", strides=2)(x)
    x = layers.Conv2DTranspose(64, 3, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(64, 3, activation="relu", padding="same", strides=2)(x)

    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    model = keras.Model(inputs, outputs)
    return model

model = get_model(img_size=img_size, num_classes=3)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  rescaling (Rescaling)       (None, 200, 200, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      36928
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 128)       147584
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 256)       590080
#
#  conv2d_transpose (Conv2DTra  (None, 25, 25, 256)      590080
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 50, 50, 256)      590080
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 50, 50, 128)      295040
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 100, 100, 128)    147584
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 100, 100, 64)     73792
#  ranspose)
#
#  conv2d_transpose_5 (Conv2DT  (None, 200, 200, 64)     36928
#  ranspose)
#
#  conv2d_6 (Conv2D)           (None, 200, 200, 3)       1731
#
# =================================================================
# Total params: 2,880,643
# Trainable params: 2,880,643
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-15 09:32:06.074908: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-15 09:32:06.705512: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13629 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:06.0, compute capability: 7.5

# %%
model.compile(optimizer="rmsprop", loss="sparse_categorical_crossentropy")

callbacks = [
    keras.callbacks.ModelCheckpoint("oxford_segmentation.keras",
                                    save_best_only=True)
]

history = model.fit(train_input_imgs, train_targets,
                    epochs=5,
                    callbacks=callbacks,
                    batch_size=64,
                    validation_data=(val_input_imgs, val_targets))
# Out:
# 2023-02-15 09:32:12.527338: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-02-15 09:32:17.950771: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fd3f4d8cd80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-02-15 09:32:17.950987: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2023-02-15 09:32:17.955397: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-02-15 09:32:18.043216: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/100 [==============================] - 75s 636ms/step - loss: 0.9502 - val_loss: 0.9217

# %%
epochs = range(1, len(history.history["loss"]) + 1)
loss = history.history["loss"]
val_loss = history.history["val_loss"]
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()

# %%
from tensorflow.keras.utils import array_to_img

model = keras.models.load_model("oxford_segmentation.keras")

i = 4
test_image = val_input_imgs[i]
plt.axis("off")
plt.imshow(array_to_img(test_image))

mask = model.predict(np.expand_dims(test_image, 0))[0]

def display_mask(pred):
    mask = np.argmax(pred, axis=-1)
    mask *= 127
    plt.axis("off")
    plt.imshow(mask)

display_mask(mask)
# Out:
# 1/1 [==============================] - 1s 509ms/step

# %% [markdown]
# # Layer visualization

# %%
model = keras.models.load_model("models/convnet_from_scratch_with_augmentation.keras")
model.summary()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_12 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_4 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 18, 18, 256)       295168
#
#  max_pooling2d_7 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 7, 7, 256)         590080
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dropout (Dropout)           (None, 12544)             0
#
#  dense_1 (Dense)             (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
import numpy as np

img_path = keras.utils.get_file(
    fname="cat.jpg",
    origin="https://img-datasets.s3.amazonaws.com/cat.jpg")

def get_img_array(img_path, target_size):
    img = keras.utils.load_img(
        img_path, target_size=target_size)
    array = keras.utils.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array

img_tensor = get_img_array(img_path, target_size=(180, 180))
# Out:
# Downloading data from https://img-datasets.s3.amazonaws.com/cat.jpg
# 80329/80329 [==============================] - 0s 1us/step

# %%
import matplotlib.pyplot as plt
plt.axis("off")
plt.imshow(img_tensor[0].astype("uint8"))
plt.show()

# %%
from tensorflow.keras import layers

layer_outputs = []
layer_names = []
for layer in model.layers:
    if isinstance(layer, (layers.Conv2D, layers.MaxPooling2D)):
        layer_outputs.append(layer.output)
        layer_names.append(layer.name)
activation_model = keras.Model(inputs=model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(img_tensor)

# %%
first_layer_activation = activations[0]
print(first_layer_activation.shape)

# %%
import matplotlib.pyplot as plt
plt.matshow(first_layer_activation[0, :, :, 5], cmap="viridis")

# %%
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]
    n_cols = n_features // images_per_row
    display_grid = np.zeros(((size + 1) * n_cols - 1,
                             images_per_row * (size + 1) - 1))
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_index = col * images_per_row + row
            channel_image = layer_activation[0, :, :, channel_index].copy()
            if channel_image.sum() != 0:
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype("uint8")
            display_grid[
                col * (size + 1): (col + 1) * size + col,
                row * (size + 1) : (row + 1) * size + row] = channel_image
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.axis("off")
    plt.imshow(display_grid, aspect="auto", cmap="viridis")
